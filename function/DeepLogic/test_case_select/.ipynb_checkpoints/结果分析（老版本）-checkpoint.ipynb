# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

dict = {
    "deeplogic": "#e7298a",
    "deepgini": "#d95f02",
    "random": "black",
    "lsc_ctm": "bisque",
    "dsc": "MediumBlue",
    "deepentropy": "royalblue",
    "tknc_cam": "Gray",
    "mcp": "red",
    "nac": "#1b9e77",
    "nbc": "#66a61e",
    "snac_ctm": 'royalblue',
    "snac_cam": 'Mediumblue',
    "kmnc_cam": "skyblue"
}

"""
apfd图像绘制
"""


# 获得图片标签,颜色,渐变,图线
def get_label(p):
    p = os.path.splitext(p)[0]
    l = p
    ls = "-"
    al = 0.7
    c = "black"

    if p.find("deeplogic_cam") > -1:
        l = "deeplogic"
        al = 1
        c = dict["deeplogic_cam"]
    else:
        temp_arr = p.split("_")
        cover_method = temp_arr[0]
        dataset_name = temp_arr[1]
        if temp_arr[2] == "adv":
            is_adv = True
            idx = 1
        else:
            is_adv = False
            idx = 0
        metrics = temp_arr[2 + idx]
        if p.find("LSC") > -1:
            args = "(1000,100)"
        elif p.find("DSC") > -1:
            args = "(1000,2)"
        else:
            args = "({})".format(temp_arr[-1])
        l = "{}".format(metrics.upper())
        if cover_method == "cam":
            ls = "-"
        else:
            ls = "-"
        c = dict["{}".format(metrics.lower())]
    return l, ls, al, c


# 图像绘制
def plot_apfd(data_path, outputdir, use_adv, metrics_arr=None, idx=0,
              cover="all", ):
    def metrics_filter_func(path: str):
        flag = False
        for met in metrics_arr:
            if path.find(met) > -1:
                flag = True
                break
        return flag

    list1 = os.listdir(data_path)
    if use_adv:
        list_file = list(filter(lambda x: x.split("_")[2] == "adv", list1))
    else:
        # print(list1)
        # print("filter adv")
        list_file = list(filter(lambda x: x.split("_")[2] != "adv", list1))
        print(list_file)
    if cover == "cam":
        list_file = list(filter(lambda x: x.split("_")[0] == "cam", list_file))
    elif cover == "ctm":
        list_file = list(filter(lambda x: x.split("_")[0] == "ctm", list_file))
    else:
        list_file = list_file
    if metrics_arr is not None:
        # 只选出过滤后的文件
        list_file = list(filter(metrics_filter_func, list_file))
    for i, p in enumerate(list_file):
        l, ls, al, c = get_label(p)
        df_res = pd.read_csv("{}{}".format(data_path, p))
        col = df_res.iloc[:, [0]]
        max_num = col.max().values[0]
        col = col.apply(lambda x: x / max_num * 100)
        col2 = np.array(list(range(len(df_res)))) / (len(df_res) - 1) * 100
        plt.plot(col2, col.values, label=l, alpha=al, color=c, linestyle=ls)
    plt.xlabel("Percentage of test case executed")
    plt.ylabel("Percentage of fault detected")
    plt.legend()
    plt.grid(linestyle='--')
    res_path = "{}{}.pdf".format(outputdir, idx)
    plt.savefig(res_path, bbox_inches='tight')
    res_path = "{}{}.png".format(outputdir, idx)
    plt.savefig(res_path, bbox_inches='tight')
    plt.close()

# %%
# 参数配置
params = [
    {
        "use_adv": False,  # 是否使用adv
        "metrics_arr": ["dsc","mcp","nac","nbc","random","deepgini","deeplogic","deepentropy"],  # 选择绘制的图线
        "cover": "cam",  # 选择覆盖的方法
        "idx": 6,  # 图片编号
    },

]

input_base_path = "./result/apfd_figure_csv"
output_base_path = "./result/fig"
#dir_list = ["mnist", "cifar", "fashion", "svhn"]
dir_list = ["cifar","fashionminist"]
for dataset_name in dir_list:
    lst = os.listdir(input_base_path + '/' + dataset_name)
    for model_name in lst:  # 遍历每个模型
        inputdir = input_base_path + '/' + dataset_name + "/" + model_name + "/"
        outputdir = output_base_path + "/" + dataset_name + "/" + model_name + "/"
        if not os.path.exists(outputdir):
            os.makedirs(outputdir)
        for param in params:
            use_adv, metrics_arr, cover, idx = param["use_adv"], param["metrics_arr"], param["cover"], param["idx"]
            print("plot {} {} {}".format(dataset_name, model_name, idx))
            plot_apfd(inputdir, outputdir, use_adv, metrics_arr=metrics_arr, idx=idx, cover=cover)
# Out:
# plot cifar vgg16 6
# ['ctm_cifar_deepgini_0.csv', 'cam_cifar_deepentropy_0.csv', 'cam_cifar_dsc_0.csv', 'cam_cifar_deepgini_0.csv', 'cam_cifar_deeplogic_0.csv', 'cam_cifar_nbc_0.csv', 'ctm_cifar_nac_0.csv', 'cam_cifar_nac_0.csv', 'cam_cifar_mcp_0.csv', 'cam_cifar_random_0.csv', 'ctm_cifar_nbc_0.csv']
# plot cifar resnet18 6
# ['ctm_cifar_deepgini_0.csv', 'cam_cifar_deepentropy_0.csv', 'cam_cifar_deepgini_0.csv', 'cam_cifar_deeplogic_0.csv', 'cam_cifar_nbc_0.csv', 'ctm_cifar_nac_0.csv', 'cam_cifar_nac_0.csv', 'cam_cifar_mcp_0.csv', 'cam_cifar_random_0.csv', 'ctm_cifar_nbc_0.csv']
# plot fashionminist smallcnn 6
# ['cam_fashionminist_deepentropy_0.csv', 'ctm_fashionminist_deepgini_0.csv', 'cam_fashionminist_deeplogic_0.csv', 'cam_fashionminist_deepgini_0.csv']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 18), dpi=40)
img=plt.imread('./result/fig/cifar/vgg16/6.png')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 18), dpi=40)
img=plt.imread('./result/fig/cifar/resnet18/6.png')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(19, 20), dpi=40)
img=plt.imread('./result/fig/fashionminist/smallcnn/6.png')
plt.imshow(img)
